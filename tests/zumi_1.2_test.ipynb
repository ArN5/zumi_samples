# %%
from zumi.zumi import Zumi
import time

time_start=time.time()
zumi = Zumi()
print("time taken ",time.time()-time_start)

sensor_data = zumi.get_all_sensor_data()

#prints all the zumi sensors in a list with a time stamp
print(sensor_data)

#grabs the current zumi board firmware version
print("zumi board firmware version ",sensor_data[9])

#checks if the zumi board has the compass i2c address
print("zumi has compass =", zumi.has_compass)

#the current coordinate zumi predicts 
#to be using the best fit line speed prediction
print(zumi.coordinate)

#what i2c addresses are found
print(zumi.sensors_found)
# Out:
# Starting Zumi
# Pi Zero I2C is available
# Verified Pi Zero is the same
# Gyroscope previously calibrated
# Zumi board detected
# Compass detected
# OLED Screen detected
# Gyroscope & Accelerometer detected
# time taken  0.17559170722961426
# [1589206989.9240725, 241, 192, 223, 203, 234, 244, 1.1206896551724137, 5.145833333333334, 1.2, 0, 0.18798828125, 0.019775390625, 0.980712890625, -0.14020810657969296, -0.11665076688798076, 0.0826989359943191, 32.85941176470588, -0.02025051333737821, -0.01684808366866988, 0.011944358619435921, 1.155172838159833, -10.851136469748475, 0.003257953692566016, -0.23353385139026597, 0.044923901244568507, -4.05795573673035, 87.910517286664, 5, 362, 1342, 1447, 990, 74.82843985344118]
# zumi board firmware version  1.2
# zumi has compass = True
# [0, 0]
# [4, 13, 60, 104]

# %%
#tries to drive forward with 
#a gradual speed increase
zumi.smooth_forward(duration=1)
zumi.smooth_reverse(duration=1)

# %%
zumi.reset_gyro()

zumi.smooth_turn_left(90)
zumi.smooth_turn_right(90,speed=30,step=1)

# %%
zumi.reset_gyro()
inches= 12
degree=0

print("predicted speed in inches per second", zumi.PRED_SPEED_INCHES_SEC)
print("slope intercept of predicted speed per inches",zumi.PRED_SLOPE_INT_INCH)

zumi.move_inches(inches,degree)
# Out:
# 6
# 0
# ([-0.019302787113005985,
#   -0.010749354818276238,
#   -0.0481428101750611,
#   -0.09387392259123437,
#   -0.1588092148245988,
#   -0.2750014393312905,
#   -0.4378533151415114,
#   -0.6382477788817345,
#   -0.7855217934584529,
#   -0.9102198013171978,
#   -1.105136628519231,
#   -1.1326932106734873,
#   -1.3006215339583125,
#   -1.219930579130049,
#   -0.9963556444377714,
#   -0.7166382260914106,
#   -0.3709167491047863,
#   -0.05324820202978059,
#   0.04861016050608183,
#   0.21724578865828473,
#   0.15299424704554848,
#   0.15988050478373375,
#   0.08218331732711293,
#   -0.091970174195247,
#   -0.2869091394166879,
#   -0.5275927813457466,
#   -0.5699334722508619,
#   -0.5882246714642708,
#   -0.7518905422106552,
#   -0.6815136991036558,
#   -0.5841385169082352,
#   -0.35463086639044117,
#   -0.14802073923369644,
#   -0.052178162314127974,
#   0.13117376307964285,
#   0.14315308809908886,
#   0.18816544477808334,
#   0.16928201388041578,
#   0.12282470340846294,
#   0.055237459064343575,
#   0.842991828918457,
#   0.861400842666626,
#   0.8798158168792725,
#   0.8981964588165283,
#   0.9167280197143555,
#   0.9350674152374268,
#   0.9537386894226074,
#   0.9721312522888184,
#   0.9905178546905518,
#   1.0089125633239746,
#   1.027463674545288,
#   1.0460169315338135,
#   1.0645091533660889,
#   1.0828924179077148,
#   1.1050255298614502,
#   1.1233646869659424,
#   1.1416435241699219,
#   1.1599504947662354,
#   1.1782898902893066,
#   1.19677734375,
#   1.2153286933898926,
#   1.2339112758636475,
#   1.2521886825561523,
#   1.2706143856048584,
#   1.290215253829956,
#   1.3089115619659424,
#   1.3276009559631348,
#   1.3462951183319092,
#   1.3646695613861084,
#   1.38309907913208,
#   1.4015469551086426,
#   1.4199621677398682,
#   1.4383163452148438,
#   1.4566657543182373,
#   1.4750871658325195,
#   1.493448257446289,
#   1.5117976665496826,
#   1.5302152633666992,
#   1.548607349395752,
#   1.5669987201690674,
#   1.5853981971740723,
#   1.603950023651123,
#   1.6223065853118896,
#   1.640791416168213,
#   1.6592795848846436,
#   1.6776328086853027,
#   1.6960444450378418,
#   1.7144532203674316,
#   1.7328252792358398,
#   1.7512574195861816,
#   1.769669771194458,
#   1.7880752086639404,
#   1.8064155578613281,
#   1.824772596359253,
#   1.8434925079345703,
#   1.8622164726257324,
#   1.8809845447540283,
#   1.8993489742279053,
#   1.917752742767334,
#   1.9361002445220947,
#   1.9545574188232422,
#   1.9729838371276855,
#   1.991468906402588,
#   2.009854555130005],
#  11.089243298321676,
#  1.7290024003892286)

# %%
from zumi.zumi import Zumi
import time

zumi = Zumi()

zumi.reset_coordinate()
zumi.reset_gyro()
#zumi.mpu.calibrate_MPU(400)
# zumi.mpu.print_offsets()

zumi.PRED_SPEED_INCHES_SEC = 6 
zumi.PRED_SLOPE_INT_INCH = -1
distance_in_inches = 6


zumi.move_to_coordinate(3,0)#get on road
zumi.move_to_coordinate(3,-6)#drive to the right
zumi.move_to_coordinate(-13,-6)#
zumi.move_to_coordinate(-13,7)
zumi.turn_left(90)


# zumi.move_to_coordinate(distance_in_inches,0)
# zumi.move_to_coordinate(distance_in_inches,distance_in_inches)
# zumi.move_to_coordinate(0,distance_in_inches)
# zumi.move_to_coordinate(0,0)
# zumi.move_to_coordinate(distance_in_inches,0)
# zumi.move_to_coordinate(distance_in_inches,distance_in_inches)
# Out:
# Starting Zumi
# Pi Zero I2C is available
# Verified Pi Zero is the same
# Gyroscope previously calibrated
# Zumi board detected
# Compass detected
# OLED Screen detected
# Gyroscope & Accelerometer detected

# %%
zumi.reset_gyro()
inches= 12
degree=0
#can adjust PID parameters.
zumi.move_inches(inches,degree,k_p=10,k_i=20,k_d=0.2)
print("done")
# Out:
# done

# %%
print(zumi.get_board_firmware_version())
# Out:
# 1.2
